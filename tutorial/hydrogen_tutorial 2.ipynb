# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab
import tikzplotlib
from qiskit import Aer
from qiskit.aqua import QuantumInstance, aqua_globals
from qiskit.aqua.algorithms import NumPyEigensolver
from qiskit.aqua.algorithms import VQE
from qiskit.aqua.components.initial_states import Zero
from qiskit.aqua.components.optimizers import SPSA
from qiskit.aqua.operators import WeightedPauliOperator
from qiskit.chemistry import FermionicOperator
from qiskit.chemistry.components.initial_states import HartreeFock
from qiskit.chemistry.components.variational_forms import UCCSD
from qiskit.chemistry.drivers import PySCFDriver, UnitsType
from qiskit.circuit.library import EfficientSU2
from qiskit.ignis.mitigation.measurement import CompleteMeasFitter
from qiskit.providers.aer import QasmSimulator, AerProvider
from qiskit.providers.aer.noise import NoiseModel
from qiskit.test.mock import *

# %%
plt.rcParams["figure.dpi"] = 100
plt.style.use("seaborn")

# %%
basis_sets = ['sto3g', '631g', 'ccpvdz']
threshold = 0.00000001
aqua_globals.random_seed = 500

# %%
def get_qubit_hamiltonian(d, basis_set, map_type='jordan_wigner'):
    """
    Obtain the qubit operators from the fermionic operators after second quantization.
    Args:
        d: inter-atomic distance
        basis_set: computational chemistry basis set
        map_type: encoding method

    Returns: qubit Hamiltonian as a weighted summed of Paulis, energy shift because of nuclear repulsion, number of particles and number of spin orbitals

    """
    driver = PySCFDriver(atom="H .0 .0 .0; H .0 .0 " + str(d) ,
                         unit=UnitsType.ANGSTROM,
                         charge=0,
                         spin=0,
                         basis=basis_set)
    molecule = driver.run()
    h1 = molecule.one_body_integrals
    h2 = molecule.two_body_integrals
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    repulsion_energy = molecule.nuclear_repulsion_energy
    fermionic_op = FermionicOperator(h1,h2)
    qubit_op = fermionic_op.mapping(map_type=map_type, threshold=threshold)
    return qubit_op, repulsion_energy, num_particles, num_spin_orbitals

# %%
qubit_ops = {}
for set in basis_sets:
    qubit_ops["qubitOp_{0}".format(set)],_,_,_ = get_qubit_hamiltonian(0.735, set)

for label in qubit_ops:
    print("\n --- {} ---".format(label),qubit_ops[label])
# Out:
#  --- qubitOp_sto3g --- Representation: paulis, qubits: 4, size: 15
#
#  --- qubitOp_631g --- Representation: paulis, qubits: 8, size: 185
#
#  --- qubitOp_ccpvdz --- Representation: paulis, qubits: 20, size: 2951

# %%
bond_lengths = np.linspace(0.1, 3.5, 30)

# %%
devices = ["fake_valencia", "fake_valencia_with_mitigation"]

# %%
def construct_qinstance(device):
    """
    Create a quantum instance with required backend properties including noise models

    Args:
        device:  high performance simulator backend to be used
            qasm_simulator : ideal multi-shot execution of qiskit circuits and returns counts or memory
            fake_valencia : simulation of an actual device - Valencia backend
            fake_valencia_with_mitigation : simulation of an actual device - Valencia backend with error mitigation applied

    Returns: QuantumInstance obj

    """
    simulator_backend = Aer.get_backend('qasm_simulator')

    device_backend = FakeValencia()
    qubit_connectivity = device_backend.configuration().coupling_map
    noise_model = NoiseModel.from_backend(device_backend)

    if device == "qasm_ideal":
        qinstance = QuantumInstance(backend=simulator_backend,
                                    seed_simulator=aqua_globals.random_seed)

    elif device == "fake_valencia":
        simulator = QasmSimulator(provider=AerProvider(), method='density_matrix')
        qinstance = QuantumInstance(backend=simulator,
                                    noise_model=noise_model,
                                    coupling_map=qubit_connectivity,
                                    seed_simulator=aqua_globals.random_seed,
                                    seed_transpiler=aqua_globals.random_seed)

    elif device == "fake_valencia_with_mitigation":
        simulator = QasmSimulator(provider=AerProvider(), method='density_matrix')
        qinstance = QuantumInstance(backend=simulator,
                                    seed_simulator=aqua_globals.random_seed,
                                    seed_transpiler=aqua_globals.random_seed,
                                    noise_model=noise_model,
                                    measurement_error_mitigation_cls=CompleteMeasFitter,
                                    cals_matrix_refresh_period=30)
    return qinstance

# %%
exact_energies = []

vqe_energies_effSU2 = []
vqe_energies_uccsd = []
vqe_energies_effSU2_fake = []
vqe_energies_effSU2_fake_mit = []


counts_effSU2 = []
values_effSU2 = []
counts_effSU2_fake = []
values_effSU2_fake = []
counts_effSU2_fake_mit = []
values_effSU2_fake_mit = []

counts_uccsd = []
values_uccsd = []

# %%
def store_intermediate_result_uccsd(eval_count, parameters, mean, std):
    """
    Callback function for VQE that enables storange of intermediate values
    Args:
        eval_count: number of evaluations for convergence
        parameters: variational paratmeters
        mean: mean value
        std: standard deviation

    Returns:
        counts, mean

    """
    counts_uccsd.append(eval_count)
    values_uccsd.append(mean)
    return counts_uccsd, values_uccsd

def store_intermediate_result_effSU2(eval_count, parameters, mean, std):
    counts_effSU2.append(eval_count)
    values_effSU2.append(mean)
    return counts_effSU2, values_effSU2

def store_intermediate_result_effSU2_fake(eval_count, parameters, mean, std):
    counts_effSU2_fake.append(eval_count)
    values_effSU2_fake.append(mean)
    return counts_effSU2_fake, values_effSU2_fake

def store_intermediate_result_effSU2_fake_mit(eval_count, parameters, mean, std):
    counts_effSU2_fake_mit.append(eval_count)
    values_effSU2_fake_mit.append(mean)
    return counts_effSU2_fake_mit, values_effSU2_fake_mit

# %%
for dist in bond_lengths:
    qubitOp, shift, num_particles, num_spin_orbitals = get_qubit_hamiltonian(dist,basis_set='sto3g')
    result = NumPyEigensolver(qubitOp).run()
    exact_energy = np.real(result.eigenvalues) + shift
    exact_energies.append(exact_energy) 
    initial_state = HartreeFock(num_spin_orbitals,
                                num_particles,
                                two_qubit_reduction=False,
                                qubit_mapping='jordan_wigner')
    optimizer = SPSA(maxiter=200)

    ansatz = [UCCSD(num_orbitals= num_spin_orbitals,
                    num_particles= num_particles,
                    initial_state= initial_state,
                    qubit_mapping='jordan_wigner',
                    two_qubit_reduction=False,),
              EfficientSU2(num_qubits=qubitOp.num_qubits,
                           su2_gates=['rz','rx','rz'],
                           initial_state=Zero(qubitOp.num_qubits))]
    for psi in ansatz:
        if psi == ansatz[0]:
            print("----UCCSD----")
            vqe = VQE(qubitOp, psi, optimizer, callback=store_intermediate_result_uccsd)
            vqe_result = np.real(vqe.run(construct_qinstance('qasm_ideal'))['eigenvalue'] + shift)
            vqe_energies_uccsd.append(vqe_result)
            print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result)

        elif psi == ansatz[1]:
            print("----Hardware Efficient Ansatz----")
            vqe = VQE(qubitOp, psi, optimizer, callback=store_intermediate_result_effSU2)
            vqe_result = np.real(vqe.run(construct_qinstance('qasm_ideal'))['eigenvalue'] + shift)
            vqe_energies_effSU2.append(vqe_result)
            print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result)

            for device in devices:
                if device == "fake_valencia":
                    vqe = VQE(qubitOp, psi, optimizer, callback=store_intermediate_result_effSU2_fake)
                    vqe_result = np.real(vqe.run(construct_qinstance(device))['eigenvalue'] + shift)
                    vqe_energies_effSU2_fake.append(vqe_result)
                elif device == "fake_valencia_with_mitigation":
                    vqe = VQE(qubitOp, psi, optimizer, callback=store_intermediate_result_effSU2_fake_mit)
                    vqe_result = np.real(vqe.run(construct_qinstance(device))['eigenvalue'] + shift)
                    vqe_energies_effSU2_fake_mit.append(vqe_result)
                print('---{}---'.format(device),"Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result)
# Out:
# ----UCCSD----
# Interatomic Distance: 0.1 VQE Result: 2.701856471576982
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.1 VQE Result: 2.9347999030682512
# ---fake_valencia--- Interatomic Distance: 0.1 VQE Result: 3.1138882979396207
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.1 VQE Result: 3.056281431884058
# ----UCCSD----
# Interatomic Distance: 0.22 VQE Result: -0.04146826459933539
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.22 VQE Result: 0.48193291740097566
# ---fake_valencia--- Interatomic Distance: 0.22 VQE Result: 1.2499581358778822
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.22 VQE Result: 0.5163915095262528
# ----UCCSD----
# Interatomic Distance: 0.33 VQE Result: -0.7439000354402978
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.33 VQE Result: -0.3377294339279444
# ---fake_valencia--- Interatomic Distance: 0.33 VQE Result: 0.6810255447288369
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.33 VQE Result: 1.3199107512583852
# ----UCCSD----
# Interatomic Distance: 0.45 VQE Result: -0.9978597990661131
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.45 VQE Result: -0.5175581261553741
# ---fake_valencia--- Interatomic Distance: 0.45 VQE Result: 0.20912188767372275
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.45 VQE Result: 0.15094102735811865
# ----UCCSD----
# Interatomic Distance: 0.57 VQE Result: -1.0988778915083306
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.57 VQE Result: -0.9626718836163158
# ---fake_valencia--- Interatomic Distance: 0.57 VQE Result: -0.20178246653801757
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.57 VQE Result: 0.0863521733503978
# ----UCCSD----
# Interatomic Distance: 0.69 VQE Result: -1.1334467583688692
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.69 VQE Result: -1.0434057433951969
# ---fake_valencia--- Interatomic Distance: 0.69 VQE Result: -0.36148629818595135
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.69 VQE Result: -0.1605031107137027
# ----UCCSD----
# Interatomic Distance: 0.8 VQE Result: -1.1356335653496394
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.8 VQE Result: -0.8558739294609757
# ---fake_valencia--- Interatomic Distance: 0.8 VQE Result: -0.594184559272729
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.8 VQE Result: -0.12388641071759066
# ----UCCSD----
# Interatomic Distance: 0.92 VQE Result: -1.1213755191173391
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 0.92 VQE Result: -0.8483242019901105
# ---fake_valencia--- Interatomic Distance: 0.92 VQE Result: -0.32726416271528214
# ---fake_valencia_with_mitigation--- Interatomic Distance: 0.92 VQE Result: -0.297426023317242
# ----UCCSD----
# Interatomic Distance: 1.04 VQE Result: -1.0954605003264652
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.04 VQE Result: -1.050459507367054
# ---fake_valencia--- Interatomic Distance: 1.04 VQE Result: -0.776517431079043
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.04 VQE Result: -0.2669785403120468
# ----UCCSD----
# Interatomic Distance: 1.16 VQE Result: -1.0678819823632315
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.16 VQE Result: -0.9897614282803529
# ---fake_valencia--- Interatomic Distance: 1.16 VQE Result: -0.4836952247939065
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.16 VQE Result: -0.3972029575111079
# ----UCCSD----
# Interatomic Distance: 1.27 VQE Result: -1.040423459432396
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.27 VQE Result: -0.9915668433022573
# ---fake_valencia--- Interatomic Distance: 1.27 VQE Result: -0.7105640403684876
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.27 VQE Result: -0.5054322417517201
# ----UCCSD----
# Interatomic Distance: 1.39 VQE Result: -1.0196464675385841
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.39 VQE Result: -0.859356947519493
# ---fake_valencia--- Interatomic Distance: 1.39 VQE Result: -0.4363732322718361
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.39 VQE Result: -0.5145481314795103
# ----UCCSD----
# Interatomic Distance: 1.51 VQE Result: -1.0016870653182766
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.51 VQE Result: -0.82103902435649
# ---fake_valencia--- Interatomic Distance: 1.51 VQE Result: -0.6547539617419429
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.51 VQE Result: -0.4588226490706517
# ----UCCSD----
# Interatomic Distance: 1.62 VQE Result: -0.9792918636174643
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.62 VQE Result: -0.7102748538980159
# ---fake_valencia--- Interatomic Distance: 1.62 VQE Result: -0.5877114495169085
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.62 VQE Result: -0.4377699121949224
# ----UCCSD----
# Interatomic Distance: 1.74 VQE Result: -0.9684138951250734
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.74 VQE Result: -0.8971746696669709
# ---fake_valencia--- Interatomic Distance: 1.74 VQE Result: -0.536085588946267
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.74 VQE Result: -0.5237314269045972
# ----UCCSD----
# Interatomic Distance: 1.86 VQE Result: -0.9602009591300698
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.86 VQE Result: -0.8629851138517135
# ---fake_valencia--- Interatomic Distance: 1.86 VQE Result: -0.6223765161246237
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.86 VQE Result: -0.533003774824093
# ----UCCSD----
# Interatomic Distance: 1.98 VQE Result: -0.9515148304622656
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 1.98 VQE Result: -0.9010563936879461
# ---fake_valencia--- Interatomic Distance: 1.98 VQE Result: -0.5251347263334505
# ---fake_valencia_with_mitigation--- Interatomic Distance: 1.98 VQE Result: -0.4420572211275578
# ----UCCSD----
# Interatomic Distance: 2.09 VQE Result: -0.9445210819686742
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.09 VQE Result: -0.9131709525491285
# ---fake_valencia--- Interatomic Distance: 2.09 VQE Result: -0.579329016387498
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.09 VQE Result: -0.603425091507046
# ----UCCSD----
# Interatomic Distance: 2.21 VQE Result: -0.9383250247249544
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.21 VQE Result: -0.9194828631334788
# ---fake_valencia--- Interatomic Distance: 2.21 VQE Result: -0.6274523061948627
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.21 VQE Result: -0.40464280239151457
# ----UCCSD----
# Interatomic Distance: 2.33 VQE Result: -0.9373875637688631
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.33 VQE Result: -0.90587048663922
# ---fake_valencia--- Interatomic Distance: 2.33 VQE Result: -0.6269430477991831
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.33 VQE Result: -0.4796276371311696
# ----UCCSD----
# Interatomic Distance: 2.44 VQE Result: -0.9348972190235628
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.44 VQE Result: -0.9285132772647221
# ---fake_valencia--- Interatomic Distance: 2.44 VQE Result: -0.6222441487053895
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.44 VQE Result: -0.5951587090942799
# ----UCCSD----
# Interatomic Distance: 2.56 VQE Result: -0.9352144867389341
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.56 VQE Result: -0.841286385035425
# ---fake_valencia--- Interatomic Distance: 2.56 VQE Result: -0.5860178276051768
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.56 VQE Result: -0.492216679242241
# ----UCCSD----
# Interatomic Distance: 2.68 VQE Result: -0.9348246853644833
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.68 VQE Result: -0.846543210033982
# ---fake_valencia--- Interatomic Distance: 2.68 VQE Result: -0.5650631145866521
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.68 VQE Result: -0.6113967488171088
# ----UCCSD----
# Interatomic Distance: 2.8 VQE Result: -0.934309059566844
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.8 VQE Result: -0.8822121375366081
# ---fake_valencia--- Interatomic Distance: 2.8 VQE Result: -0.5691225132857115
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.8 VQE Result: -0.6228973911404354
# ----UCCSD----
# Interatomic Distance: 2.91 VQE Result: -0.9340723951623568
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 2.91 VQE Result: -0.9280960328857122
# ---fake_valencia--- Interatomic Distance: 2.91 VQE Result: -0.5872425824772728
# ---fake_valencia_with_mitigation--- Interatomic Distance: 2.91 VQE Result: -0.6189363361427348
# ----UCCSD----
# Interatomic Distance: 3.03 VQE Result: -0.9334393668822375
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 3.03 VQE Result: -0.8290046868787965
# ---fake_valencia--- Interatomic Distance: 3.03 VQE Result: -0.47849392318253947
# ---fake_valencia_with_mitigation--- Interatomic Distance: 3.03 VQE Result: -0.6593820150675203
# ----UCCSD----
# Interatomic Distance: 3.15 VQE Result: -0.9331751016469864
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 3.15 VQE Result: -0.8992127780982636
# ---fake_valencia--- Interatomic Distance: 3.15 VQE Result: -0.5708007049443417
# ---fake_valencia_with_mitigation--- Interatomic Distance: 3.15 VQE Result: -0.4231123888433562
# ----UCCSD----
# Interatomic Distance: 3.27 VQE Result: -0.9327398512203164
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 3.27 VQE Result: -0.821023565734105
# ---fake_valencia--- Interatomic Distance: 3.27 VQE Result: -0.5741588059505442
# ---fake_valencia_with_mitigation--- Interatomic Distance: 3.27 VQE Result: -0.540679997371124
# ----UCCSD----
# Interatomic Distance: 3.38 VQE Result: -0.9328865429791424
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 3.38 VQE Result: -0.8826355858145425
# ---fake_valencia--- Interatomic Distance: 3.38 VQE Result: -0.5336199587300552
# ---fake_valencia_with_mitigation--- Interatomic Distance: 3.38 VQE Result: -0.5778875638232575
# ----UCCSD----
# Interatomic Distance: 3.5 VQE Result: -0.9327327905071353
# ----Hardware Efficient Ansatz----
# Interatomic Distance: 3.5 VQE Result: -0.8754458461900373
# ---fake_valencia--- Interatomic Distance: 3.5 VQE Result: -0.5569271304259698
# ---fake_valencia_with_mitigation--- Interatomic Distance: 3.5 VQE Result: -0.6037721330120939

# %%
print(vqe_energies_effSU2_fake)
# Out:
# [3.1138882979396207, 1.2499581358778822]

# %%
plt.plot(bond_lengths, exact_energies, label='NumPy Minimum Eigensolver')
plt.plot(bond_lengths, vqe_energies_effSU2, label='VQE- Hardware efficient ansatz')
plt.plot(bond_lengths, vqe_energies_effSU2_fake, label='VQE- Hardware efficient ansatz - Valencia')
plt.plot(bond_lengths, vqe_energies_effSU2_fake_mit, label='VQE- Hardware efficient ansatz - Valencia - error mit')
plt.plot(bond_lengths, vqe_energies_uccsd, label='VQE- UCCSD')
plt.xlabel('Interatomic distance')
plt.ylabel('Energy')
plt.title(r'$H_2$ Ground State Energy')
plt.legend(loc='upper right')
tikzplotlib.save("BG_ansatz_comparison.tex")
