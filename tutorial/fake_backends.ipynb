# %%
import qiskit
from qiskit.test.mock import *
from qiskit.tools.jupyter import *
from inspect import getmembers, isclass

# %%
for member in getmembers(qiskit.test.mock, isclass):
    print(member)
# Out:
# ('Fake1Q', <class 'qiskit.test.mock.fake_1q.Fake1Q'>)
# ('FakeAlmaden', <class 'qiskit.test.mock.backends.almaden.fake_almaden.FakeAlmaden'>)
# ('FakeArmonk', <class 'qiskit.test.mock.backends.armonk.fake_armonk.FakeArmonk'>)
# ('FakeAthens', <class 'qiskit.test.mock.backends.athens.fake_athens.FakeAthens'>)
# ('FakeBackend', <class 'qiskit.test.mock.fake_backend.FakeBackend'>)
# ('FakeBoeblingen', <class 'qiskit.test.mock.backends.boeblingen.fake_boeblingen.FakeBoeblingen'>)
# ('FakeBogota', <class 'qiskit.test.mock.backends.bogota.fake_bogota.FakeBogota'>)
# ('FakeBurlington', <class 'qiskit.test.mock.backends.burlington.fake_burlington.FakeBurlington'>)
# ('FakeCambridge', <class 'qiskit.test.mock.backends.cambridge.fake_cambridge.FakeCambridge'>)
# ('FakeEssex', <class 'qiskit.test.mock.backends.essex.fake_essex.FakeEssex'>)
# ('FakeJob', <class 'qiskit.test.mock.fake_job.FakeJob'>)
# ('FakeJohannesburg', <class 'qiskit.test.mock.backends.johannesburg.fake_johannesburg.FakeJohannesburg'>)
# ('FakeLondon', <class 'qiskit.test.mock.backends.london.fake_london.FakeLondon'>)
# ('FakeManhattan', <class 'qiskit.test.mock.backends.manhattan.fake_manhattan.FakeManhattan'>)
# ('FakeMelbourne', <class 'qiskit.test.mock.backends.melbourne.fake_melbourne.FakeMelbourne'>)
# ('FakeMontreal', <class 'qiskit.test.mock.backends.montreal.fake_montreal.FakeMontreal'>)
# ('FakeOpenPulse2Q', <class 'qiskit.test.mock.fake_openpulse_2q.FakeOpenPulse2Q'>)
# ('FakeOpenPulse3Q', <class 'qiskit.test.mock.fake_openpulse_3q.FakeOpenPulse3Q'>)
# ('FakeOurense', <class 'qiskit.test.mock.backends.ourense.fake_ourense.FakeOurense'>)
# ('FakeParis', <class 'qiskit.test.mock.backends.paris.fake_paris.FakeParis'>)
# ('FakePoughkeepsie', <class 'qiskit.test.mock.backends.poughkeepsie.fake_poughkeepsie.FakePoughkeepsie'>)
# ('FakeProvider', <class 'qiskit.test.mock.fake_provider.FakeProvider'>)
# ('FakeProviderFactory', <class 'qiskit.test.mock.fake_provider.FakeProviderFactory'>)
# ('FakeQasmSimulator', <class 'qiskit.test.mock.fake_qasm_simulator.FakeQasmSimulator'>)
# ('FakeQobj', <class 'qiskit.test.mock.fake_qobj.FakeQobj'>)
# ('FakeRochester', <class 'qiskit.test.mock.backends.rochester.fake_rochester.FakeRochester'>)
# ('FakeRome', <class 'qiskit.test.mock.backends.rome.fake_rome.FakeRome'>)
# ('FakeRueschlikon', <class 'qiskit.test.mock.backends.rueschlikon.fake_rueschlikon.FakeRueschlikon'>)
# ('FakeSantiago', <class 'qiskit.test.mock.backends.santiago.fake_santiago.FakeSantiago'>)
# ('FakeSingapore', <class 'qiskit.test.mock.backends.singapore.fake_singapore.FakeSingapore'>)
# ('FakeTenerife', <class 'qiskit.test.mock.backends.tenerife.fake_tenerife.FakeTenerife'>)
# ('FakeTokyo', <class 'qiskit.test.mock.backends.tokyo.fake_tokyo.FakeTokyo'>)
# ('FakeToronto', <class 'qiskit.test.mock.backends.toronto.fake_toronto.FakeToronto'>)
# ('FakeValencia', <class 'qiskit.test.mock.backends.valencia.fake_valencia.FakeValencia'>)
# ('FakeVigo', <class 'qiskit.test.mock.backends.vigo.fake_vigo.FakeVigo'>)
# ('FakeYorktown', <class 'qiskit.test.mock.backends.yorktown.fake_yorktown.FakeYorktown'>)

# %%
fakeboeblingen = FakeBoeblingen()

# %%
fakeboeblingen
# Out:
# VBox(children=(HTML(value="<h1 style='color:#ffffff;background-color:#000000;padding-top: 1%;padding-bottom: 1…
# <FakeBoeblingen('fake_boeblingen') from None()>

# %%
fakevigo = FakeVigo()

# %%
fakevigo
# Out:
# VBox(children=(HTML(value="<h1 style='color:#ffffff;background-color:#000000;padding-top: 1%;padding-bottom: 1…
# <FakeVigo('fake_vigo') from None()>

# %%
fakevalencia = FakeValencia()

# %%
fakevalencia
# Out:
# VBox(children=(HTML(value="<h1 style='color:#ffffff;background-color:#000000;padding-top: 1%;padding-bottom: 1…
# <FakeValencia('fake_valencia') from None()>
